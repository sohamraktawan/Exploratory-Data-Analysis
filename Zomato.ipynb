# %% [markdown]
# # Exploratory Data Analysis of Zomato Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("./datasets/zomato/zomato.csv", encoding="latin-1")

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
# !pip install openpyxl

# %%
ct = pd.read_excel("./datasets/zomato/Country-Code.xlsx")

# %%
ct.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %% [markdown]
# ### Merging to make "Country" column

# %%
df = pd.merge(left=df, right=ct, on="Country Code", how="left")

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.count()
# Out:
# Restaurant ID           9551
# Restaurant Name         9551
# Country Code            9551
# City                    9551
# Address                 9551
# Locality                9551
# Locality Verbose        9551
# Longitude               9551
# Latitude                9551
# Cuisines                9542
# Average Cost for two    9551
# Currency                9551
# Has Table booking       9551
# Has Online delivery     9551
# Is delivering now       9551
# Switch to order menu    9551
# Price range             9551
# Aggregate rating        9551
# Rating color            9551
# Rating text             9551
# Votes                   9551
# Country                 9551
# dtype: int64

# %% [markdown]
# ### Checking Null Values

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# ### Drop Null values as proportion insignificant in dataset

# %%
df["Cuisines"].dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %% [markdown]
# ### Top 5 Countries by Number of Restaurants

# %%
plt.figure(figsize=(10, 10))
plt.pie(df["Country"].value_counts().nlargest(5), labels=df["Country"].value_counts().nlargest(5).index, autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1b6805be660>,
# ...
#  [Text(-1.0754537909494666, 0.23108254700955058, 'India'),
#   Text(1.057349209009404, -0.30333587029427866, 'United States'),
#   Text(1.0935476396166053, -0.11896873492204361, 'United Kingdom'),
#   Text(1.097957077612072, -0.0670093704011526, 'Brazil'),
#   Text(1.0997729487438723, -0.022348628844035323, 'South Africa')],
#  [Text(-0.5866111586997089, 0.12604502564157302, '93%'),
#   Text(0.5767359321869476, -0.1654559292514247, '5%'),
#   Text(0.5964805306999664, -0.0648920372302056, '1%'),
#   Text(0.5988856786974937, -0.03655056567335596, '1%'),
#   Text(0.5998761538602939, -0.012190161187655629, '1%')])

# %% [markdown]
# ### Top 5 Cities in India by Number of Restaurants

# %%
df[df["Country"] == "India"]["City"].value_counts().nlargest(5).plot(kind="pie", autopct="%1.2f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Top 5 Cities in UK by Number of Restaurants

# %%
df[df["Country"] == "United Kingdom"]["City"].value_counts().nlargest(5).plot(kind="pie", autopct="%1.2f%%")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### Top 5 Cities in USA by Number of Restaurants

# %%
df[df["Country"] == "United States"]["City"].value_counts().nlargest(5).plot(kind="pie", autopct="%1.2f%%", legend=False)
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ### Top 5 Localities with highest number of restaurants in New Delhi

# %%
df[df["City"] == "New Delhi"]["Locality"].value_counts().nlargest(5)
# Out:
# Locality
# Connaught Place    122
# Rajouri Garden      99
# Shahdara            87
# Defence Colony      86
# Pitampura           85
# Name: count, dtype: int64

# %% [markdown]
# ### Top 5 Localities with highest number of restaurants in Gurgaon

# %%
df[df["City"] == "Gurgaon"]["Locality"].value_counts().nlargest(5)
# Out:
# Locality
# DLF Phase 3    69
# Sector 56      54
# Sector 14      52
# Palam Vihar    49
# Sohna Road     42
# Name: count, dtype: int64

# %% [markdown]
# ### Top 5 Localities with highest number of restaurants in Noida

# %%
df[df["City"] == "Noida"]["Locality"].value_counts().nlargest(5)
# Out:
# Locality
# Sector 62     76
# Sector 18     75
# Sector 72     61
# Sector 110    53
# Sector 41     45
# Name: count, dtype: int64

# %% [markdown]
# ### Top 20 Cities in the World with Most Restaurants

# %%
df["City"].value_counts().nlargest(20)
# Out:
# City
# New Delhi          5473
# Gurgaon            1118
# Noida              1080
# Faridabad           251
# Ghaziabad            25
# Bhubaneshwar         21
# Ahmedabad            21
# Lucknow              21
# Guwahati             21
# Amritsar             21
# Sí£o Paulo           20
# Brasí_lia            20
# Doha                 20
# Cape Town            20
# Wellington City      20
# Auckland             20
# Mumbai               20
# Mangalore            20
# Ludhiana             20
# Nashik               20
# Name: count, dtype: int64

# %%
df["City"].value_counts().nlargest(20).index.tolist()
# Out:
# ['New Delhi',
#  'Gurgaon',
#  'Noida',
#  'Faridabad',
#  'Ghaziabad',
#  'Bhubaneshwar',
#  'Lucknow',
#  'Ahmedabad',
#  'Amritsar',
#  'Guwahati',
#  'Rio de Janeiro',
#  'Brasí_lia',
#  'Albany',
#  'Doha',
#  'Cape Town',
#  'Manchester',
#  'London',
#  'Edinburgh',
#  'Birmingham',
#  'Wellington City']

# %%
grouped = df[df["City"].isin(df["City"].value_counts().nlargest(20).index.tolist())].groupby("Country")
grouped

# %%
plt.title("Distribution of Restaurants having Table Booking and Online Delivery")
sns.heatmap(df.groupby(["Has Table booking", "Has Online delivery"]).count()["Restaurant ID"].unstack(), annot=True, fmt=".2f")
# Out:
# <Axes: title={'center': 'Distribution of Restaurants having Table Booking and Online Delivery'}, xlabel='Has Online delivery', ylabel='Has Table booking'>

# %% [markdown]
# ### Distribution of Restaurants delivering now

# %%
df["Is delivering now"].value_counts()
# Out:
# Is delivering now
# No     9517
# Yes      34
# Name: count, dtype: int64

# %%
plt.title("India Distribution for Online Delivery and Table booking")
sns.heatmap(df[df["Country"] == "India"].groupby(["Has Online delivery", "Has Table booking"]).count()["Restaurant ID"].unstack(), cmap="viridis",annot=True, fmt="0.2f")
# Out:
# <Axes: title={'center': 'India Distribution for Online Delivery and Table booking'}, xlabel='Has Table booking', ylabel='Has Online delivery'>

# %%
plt.title("USA Distribution for Online Delivery and Table booking")
sns.heatmap(df[df["Country"] == "United States"].groupby(["Has Online delivery", "Has Table booking"]).count()["Restaurant ID"].unstack(), cmap="viridis",annot=True, fmt="0.2f")
# Out:
# <Axes: title={'center': 'USA Distribution for Online Delivery and Table booking'}, xlabel='Has Table booking', ylabel='Has Online delivery'>

# %%
plt.title("UK Distribution for Online Delivery and Table booking")
sns.heatmap(df[df["Country"] == "United Kingdom"].groupby(["Has Online delivery", "Has Table booking"]).count()["Restaurant ID"].unstack(), cmap="viridis",annot=True, fmt="0.2f")
# Out:
# <Axes: title={'center': 'UK Distribution for Online Delivery and Table booking'}, xlabel='Has Table booking', ylabel='Has Online delivery'>

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# ### Percentage of Restaurants having Online Delivery

# %%
(df["Has Online delivery"].value_counts()/df["Has Online delivery"].count())*100
# Out:
# Has Online delivery
# No     74.313561
# Yes    25.686439
# Name: count, dtype: float64

# %% [markdown]
# ### Percentage of Restaurants having Table Booking

# %%
(df["Has Table booking"].value_counts()/df["Has Table booking"].count())*100
# Out:
# Has Table booking
# No     87.875615
# Yes    12.124385
# Name: count, dtype: float64

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# ### Distribution of each Price Range

# %%
df["Price range"].value_counts()
# Out:
# Price range
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: count, dtype: int64

# %%
df["Cuisines"]
# Out:
# 0             French, Japanese, Desserts
# 1                               Japanese
# 2       Seafood, Asian, Filipino, Indian
# 3                        Japanese, Sushi
# 4                       Japanese, Korean
#                       ...
# 9546                             Turkish
# 9547     World Cuisine, Patisserie, Cafe
# 9548              Italian, World Cuisine
# 9549                     Restaurant Cafe
# 9550                                Cafe
# Name: Cuisines, Length: 9551, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# ### Creating new Feature of "Number of Cuisines" based on "Cuisines"

# %%
df.dropna(inplace=True)
df['Number of Cuisines'] = df['Cuisines'].apply(lambda x: len(x.split(', ')))

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
plt.figure(figsize=(10, 10))
plt.title("Count of each Number of Cuisines distributed over Price Range")
sns.countplot(x='Number of Cuisines', hue='Price range', data=df)
# Out:
# <Axes: title={'center': 'Count of each Number of Cuisines distributed over Price Range'}, xlabel='Number of Cuisines', ylabel='count'>

# %% [markdown]
# ### Distribution of each Price Range

# %%
sns.countplot(x="Price range", data=df)
# Out:
# <Axes: xlabel='Price range', ylabel='count'>

# %% [markdown]
# ### Count of each Price Range distributed over Rating

# %%
sns.countplot(x="Price range", data=df, hue="Rating text")
# Out:
# <Axes: xlabel='Price range', ylabel='count'>

# %%
df["Rating text"].value_counts().plot(kind="pie", autopct="%1.2f%%")
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %% [markdown]
# ### Distribution of Non-Rated Restaurants over Countries

# %%
df[(df["Rating text"] == "Not rated") & (df["Has Online delivery"] == "No") & (df["Has Table booking"] == "No")].groupby("Country")["Rating text"].count()
# Out:
# Country
# Brazil               5
# India             1998
# United Kingdom       1
# United States        3
# Name: Rating text, dtype: int64

# %% [markdown]
# ### Number of Restaurants having No Rating, No Online Delivery, No Table Booking and No Votes

# %%
df[(df["Rating text"] == "Not rated") & (df["Has Online delivery"] == "No") & (df["Has Table booking"] == "No") & (df["Votes"] == 0)]["Restaurant ID"].count()
# Out:
# np.int64(1049)

# %% [markdown]
# ### Distribution of Count of each Aggregate Rating over Price Ranges

# %%
plt.figure(figsize=(15, 4))
sns.countplot(x="Aggregate rating", hue="Price range", data=df[df["Rating text"] != "Not rated"], palette="cool")
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='count'>

# %% [markdown]
# ### Mean Aggregate Rating in each Price Range

# %%
df.groupby("Price range")["Aggregate rating"].mean()
# Out:
# Price range
# 1    1.997476
# 2    2.941054
# 3    3.682633
# 4    3.817918
# Name: Aggregate rating, dtype: float64

# %% [markdown]
# ### Distribution of Count of each Aggregate Rating

# %%
plt.figure(figsize=(15, 4))

sns.countplot(x="Aggregate rating", hue="Rating text", data=df[df["Rating text"] != "Not rated"], palette="Greens")
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='count'>

# %% [markdown]
# ### Count of each Rating Category

# %%
df.groupby("Rating text")["Votes"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='Rating text'>

# %% [markdown]
# ### Count of each Rating Category in India

# %%
# sns.displot(data=df, y="Votes", x="Rating text")
df[df["Country"] == "India"].groupby("Rating text")["Votes"].sum().plot(kind="bar", cmap="autumn")
# Out:
# <Axes: xlabel='Rating text'>

# %% [markdown]
# ### Count of each Rating Category in USA

# %%
df[df["Country"] == "United States"].groupby("Rating text")["Votes"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='Rating text'>

# %% [markdown]
# ### Count of each Rating Category in UK

# %%
df[df["Country"] == "United Kingdom"].groupby("Rating text")["Votes"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='Rating text'>

# %% [markdown]
# ### Restaurant with Maximum Number of Votes

# %%
df[df["Votes"] == df["Votes"].max()][["Restaurant Name", "City", "Country", "Locality", "Votes", "Aggregate rating"]]
# Out:
#     Restaurant Name       City Country     Locality  Votes  Aggregate rating
# 728            Toit  Bangalore   India  Indiranagar  10934               4.8

# %% [markdown]
# ### Cities with Maximum Highest rated restaurants

# %%
df[df["Aggregate rating"] == df["Aggregate rating"].max()][["Restaurant Name", "City", "Country", "Locality"]].groupby(["City", "Country"])["Restaurant Name"].count().nlargest(5)
# Out:
# City       Country
# Dubai      UAE               3
# Jakarta    Indonesia         3
# London     United Kingdom    3
# New Delhi  India             3
# Auckland   New Zealand       2
# Name: Restaurant Name, dtype: int64

# %% [markdown]
# ### Cities with Maximum Highest rated restaurants in India

# %%
df[(df["Aggregate rating"] == df["Aggregate rating"].max()) & (df["Country"] == "India")][["Restaurant Name", "City", "Country", "Locality"]].groupby(["City", "Country"])["Restaurant Name"].count().nlargest(5)
# Out:
# City       Country
# New Delhi  India      3
# Hyderabad  India      2
# Kolkata    India      2
# Agra       India      1
# Bhopal     India      1
# Name: Restaurant Name, dtype: int64

# %% [markdown]
# ### Cities with Excellent rated restaurants in India

# %%
df[(df["Aggregate rating"] >= 4.5) & (df["Country"] == "India")][["Restaurant Name", "City", "Country", "Locality"]].groupby(["City"])["Restaurant Name"].count().nlargest(5)
# Out:
# City
# New Delhi    28
# Gurgaon      12
# Bangalore     9
# Chennai       6
# Goa           6
# Name: Restaurant Name, dtype: int64
